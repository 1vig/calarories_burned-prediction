# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ipywidgets as widgets
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from ipywidgets import interact
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\vighn\Downloads\Fitness1.csv")

# %%
df
# Out:
#       user_id        date  steps  calories_burned  distance_km  \
# 0         468  01-01-2023   4530          2543.02        16.10
# 1         879  01-01-2023  11613          1720.76         8.10
# 2         152  01-01-2023  27335          1706.35         3.57
# 3         311  01-01-2023  13459          2912.38         6.41
# 4         759  01-01-2023  15378          3344.51        17.88
# ...       ...         ...    ...              ...          ...
# 1699      786  02-01-2023  17931          1502.90        16.44
# 1700      880  02-01-2023   5853          3517.17         4.21
# 1701      857  02-01-2023   1761          3367.67        10.12
# 1702      623  02-01-2023   4034          1835.33         5.89
# 1703      734  02-01-2023   6642          1949.98        17.11
#
#       active_minutes  sleep_hours  heart_rate_avg workout_type  \
# 0                613          1.5             176      Walking
# 1                352          6.3             128      Cycling
# ...

# %%
def perform_eda(df: pd.DataFrame):
    print("========================================")
    print("Exploratory Data Analysis")
    print("========================================\n")

    print("Shape of the DataFrame:")
    print(f"Number of rows: {df.shape[0]}")
    print(f"Number of columns: {df.shape[1]}\n")

    print("========================================\n")

    print("Columns in the DataFrame:")
    for col in df.columns:
        print(col)
    print("\n========================================\n")

    print("Information about the DataFrame:")
    df.info()
    print("\n========================================\n")

    print("Number of null values in each column:")
    print(df.isnull().sum())
    print("\n========================================\n")

    print("Number of unique values in each column:")
    print(df.nunique())
    print("\n========================================\n")

    print("Descriptive statistics for each column:")
    return df.describe()
    print("\n========================================\n")

# %%
perform_eda(df)
# Out:
# ...
# Exploratory Data Analysis
# ...
#
# Shape of the DataFrame:
# Number of rows: 1704
# Number of columns: 12
#
# ...
#
# Columns in the DataFrame:
# user_id
# date
# steps
# calories_burned
# distance_km
# active_minutes
# sleep_hours
# heart_rate_avg
# workout_type
# weather_conditions
# location
# mood
#
# ...
#
# Information about the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             1704 non-null   int64
#  1   date                1704 non-null   object
#  2   steps               1704 non-null   int64
#  3   calories_burned     1704 non-null   float64
#  4   distance_km         1704 non-null   float64
#  5   active_minutes      1704 non-null   int64
#  6   sleep_hours         1704 non-null   float64
#  7   heart_rate_avg      1704 non-null   int64
#  8   workout_type        1704 non-null   object
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of       user_id        date  steps  calories_burned  distance_km  \
# 0         468  01-01-2023   4530          2543.02        16.10
# 1         879  01-01-2023  11613          1720.76         8.10
# 2         152  01-01-2023  27335          1706.35         3.57
# 3         311  01-01-2023  13459          2912.38         6.41
# 4         759  01-01-2023  15378          3344.51        17.88
# ...       ...         ...    ...              ...          ...
# 1699      786  02-01-2023  17931          1502.90        16.44
# 1700      880  02-01-2023   5853          3517.17         4.21
# 1701      857  02-01-2023   1761          3367.67        10.12
# 1702      623  02-01-2023   4034          1835.33         5.89
# 1703      734  02-01-2023   6642          1949.98        17.11
#
#       active_minutes  sleep_hours  heart_rate_avg workout_type  \
# 0                613          1.5             176      Walking
# ...

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             1704 non-null   int64
#  1   date                1704 non-null   datetime64[ns]
#  2   steps               1704 non-null   int64
#  3   calories_burned     1704 non-null   float64
#  4   distance_km         1704 non-null   float64
#  5   active_minutes      1704 non-null   int64
#  6   sleep_hours         1704 non-null   float64
#  7   heart_rate_avg      1704 non-null   int64
#  8   workout_type        1704 non-null   object
#  9   weather_conditions  1704 non-null   object
#  10  location            1704 non-null   object
#  11  mood                1704 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(4)
# memory usage: 159.9+ KB

# %%
df.head(5)
# Out:
#    user_id       date  steps  calories_burned  distance_km  active_minutes  \
# 0      468 2023-01-01   4530          2543.02        16.10             613
# 1      879 2023-01-01  11613          1720.76         8.10             352
# 2      152 2023-01-01  27335          1706.35         3.57             236
# 3      311 2023-01-01  13459          2912.38         6.41            1329
# 4      759 2023-01-01  15378          3344.51        17.88              52
#
#    sleep_hours  heart_rate_avg workout_type weather_conditions location  \
# 0          1.5             176      Walking              Clear     Park
# 1          6.3             128      Cycling                Fog     Park
# 2          6.7             134         Yoga               Snow     Park
# 3         11.6             116     Swimming               Rain   Office
# 4          7.4              84     Swimming               Rain   Office
#
#       mood
# 0    Tired
# 1    Happy
# 2  Neutral
# 3    Tired
# 4  Neutral

# %%
def plot_feature(feature):
    plt.figure(figsize=(10,6))
    df[feature].hist(bins=30)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.figtext(0.5, 0.01, 'Interactive Feature Plot', ha='center', va='center', fontsize=20)

dropdown = widgets.Dropdown(options=df.columns, description='Feature:')

widgets.interact(plot_feature, feature=dropdown);
# Out:
# interactive(children=(Dropdown(description='Feature:', options=('user_id', 'date', 'steps', 'calories_burned',…

# %%
def update_plot(x_feature, y_feature):
    fig = px.scatter(df, x=x_feature, y=y_feature)
    fig.update_layout(title=f'Scatter plot of {y_feature} vs {x_feature}')
    fig.show()

columns = df.columns.tolist()

interact(update_plot, x_feature=columns, y_feature=columns)
# Out:
# interactive(children=(Dropdown(description='x_feature', options=('user_id', 'date', 'steps', 'calories_burned'…
# <function __main__.update_plot(x_feature, y_feature)>

# %%
def update_plot(x_feature, y_feature):
    fig = px.box(df, x=x_feature, y=y_feature)
    fig.update_layout(title=f'Box Plot of {y_feature} by {x_feature}')
    fig.show()

columns = df.columns.tolist()

interact(update_plot, x_feature=columns, y_feature=columns)
# Out:
# interactive(children=(Dropdown(description='x_feature', options=('user_id', 'date', 'steps', 'calories_burned'…
# <function __main__.update_plot(x_feature, y_feature)>

# %%
df=df.drop('user_id',axis=1)

# %%
corr=df.corr()
# Out:
# C:\Users\vighn\AppData\Local\Temp\ipykernel_14636\1726683880.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # The average user in this dataset:
#
# ### Takes around 14,991 steps per day.
#
#
# ### Burns approximately 2,739 calories.
#
#
# ### Covers a distance of 9.95 kilometers.
#
#
# ### Engages in about 716 minutes of activity.
#
#
# ### Sleeps for roughly 6 hours.
#
#
# ### Maintains an average heart rate of 119 bpm.
#
#
# ### There's a wide range in activity levels, from very low  to quite high.

# %% [markdown]
# ## Workout Types
#
# Swimming, running, yoga, and walking are the most common workout types.
#
# There's a significant number of days with no recorded workout
#
# ## Weather Conditions:
#
# Snow, rain, clear, and fog are fairly evenly distributed.
#
# ## Locations:
#
# Home, gym, park, and office are the primary locations for activities.
#
# ## Mood:
#
# Happy, tired, neutral, and stressed moods are almost equally represented.
# Relationships:

# %% [markdown]
# ## Weak Correlations:
# Most of the correlations between numerical variables are very weak, suggesting that linear relationships between these variables are not strong.
#
# ## Potential Non-Linear Relationships:
# The scatter plots visually confirm the weak linear relationships.

# %% [markdown]
# # The boxplots reveals
#
# ### Workout Type: Swimming tends to have the highest calorie burn and longest distances, while yoga has the lowest. Running generally has the highest heart rate.
#
# ### Mood: Mood doesn't seem to have a strong consistent effect on calories burned, distance, or active minutes. However, stressed moods are associated with slightly higher heart rates on average.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, explained_variance_score, median_absolute_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import median_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Le=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtype=='object':
        df[i]=Le.fit_transform(df[i])

# %%
data=df.drop('date',axis=1)
data.shape
# Out:
# (1704, 10)

# %%
x=data.drop('calories_burned',axis=1)
y=data['calories_burned']

# %%
sc=StandardScaler()
scaled_data=sc.fit_transform(x)
len(scaled_data)
# Out:
# 1704

# %%
scaled_df=pd.DataFrame(scaled_data,columns=x.columns)

# %%
scaled_df
# Out:
#          steps  distance_km  active_minutes  sleep_hours  heart_rate_avg  \
# 0    -1.220098     1.079929       -0.251062    -1.289308        1.616749
# 1    -0.394018    -0.325574       -0.886724     0.067778        0.241013
# 2     1.439618    -1.121440       -1.169240     0.180868        0.412980
# 3    -0.178721    -0.622487        1.492745     1.566227       -0.102921
# 4     0.045089     1.392653       -1.617369     0.378777       -1.020079
# ...        ...          ...             ...          ...             ...
# 1699  0.342842     1.139663       -0.248627    -0.780401        0.613608
# 1700 -1.065799    -1.009000       -0.143901     0.237414       -0.991418
# 1701 -1.543043     0.029315       -1.461498     1.537954       -0.102921
# 1702 -1.277946    -0.713844        0.472277     0.576685       -0.504178
# 1703 -0.973779     1.257374        0.279873    -0.639038        1.043526
#
#       workout_type  weather_conditions  location      mood
# ...

# %%
P=PCA(n_components=0.99)
tes_reduce=P.fit_transform(scaled_df)

# %%
P.explained_variance_ratio_
# Out:
# array([0.12277675, 0.12127311, 0.11843345, 0.1165791 , 0.10948034,
#        0.10681364, 0.10432386, 0.10380065, 0.09651908])

# %%
variance_ratio=[0.11190213,0.10973996, 0.10659291, 0.10492132, 0.1008154 ,
       0.09755122, 0.0960739 , 0.09343441]

# %%
sum=0
for i in variance_ratio:
    sum+=i
    
print(sum)
# Out:
# 0.82103125

# %%
Pca=PCA(n_components=0.82103125)
reduced=Pca.fit_transform(scaled_df)

# %%
reduced
# Out:
# array([[ 1.66905003,  0.75917715, -1.33660652, ..., -1.59278713,
#          0.22938319, -0.57362361],
#        [ 0.71444742,  0.90669447, -1.04291595, ..., -0.70376718,
#         -0.55335765, -0.38394156],
#        [ 0.80787932, -2.72260177, -1.03757189, ...,  0.34252803,
#          0.1708744 , -1.09334171],
#        ...,
#        [ 0.50090858,  1.10424372,  1.10534802, ..., -1.15492812,
#          1.01324396, -0.16727106],
#        [-0.47277791,  0.40684369, -0.72486094, ...,  0.0478014 ,
#          0.31287142, -1.26815449],
#        [ 0.36031941,  0.01402169,  0.04006769, ..., -0.74997793,
#         -0.11496831,  0.58925843]])

# %%
reduced.shape
# Out:
# (1704, 8)

# %%
columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8']

# %%
reduced_df=pd.DataFrame(reduced,columns=columns)

# %%
reduced_df.head(1)
# Out:
#        PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  1.66905  0.759177 -1.336607  2.205649  0.829924 -1.592787  0.229383
#
#         PC8
# 0 -0.573624

# %%
data.head(1)
# Out:
#    steps  calories_burned  distance_km  active_minutes  sleep_hours  \
# 0   4530          2543.02         16.1             613          1.5
#
#    heart_rate_avg  workout_type  weather_conditions  location  mood
# 0             176             5                   0         4     3

# %%
reduced[0]
# Out:
# array([ 1.66905003,  0.75917715, -1.33660652,  2.20564876,  0.82992395,
#        -1.59278713,  0.22938319, -0.57362361])

# %%
x_train,x_test,y_train,y_test=train_test_split(reduced,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (1363, 8)

# %%
x_test.shape
# Out:
# (341, 8)

# %%
y_train.shape
# Out:
# (1363,)

# %%
y_test.shape
# Out:
# (341,)

# %%
Lr=LinearRegression()

# %%
Lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
Lr_pred=Lr.predict(x_test)

# %%
dt_regressor = DecisionTreeRegressor(random_state=42)

# %%
dt_regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
dt_pred = dt_regressor.predict(x_test)

# %%
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
rf_regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_pred = rf_regressor.predict(x_test)

# %%
gb_regressor = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)

# %%
gb_regressor.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
gb_pred = gb_regressor.predict(x_test)

# %%
mse_gb = mean_squared_error(y_test, gb_pred)
mse_rf = mean_squared_error(y_test, rf_pred)
mse_dt = mean_squared_error(y_test, dt_pred)
mse_lr = mean_squared_error(y_test, Lr_pred)

r2_gb = r2_score(y_test, gb_pred)
r2_rf = r2_score(y_test, rf_pred)
r2_dt = r2_score(y_test, dt_pred)
r2_lr = r2_score(y_test, Lr_pred)

mae_gb = mean_absolute_error(y_test, gb_pred)
mae_rf = mean_absolute_error(y_test, rf_pred)
mae_dt = mean_absolute_error(y_test, dt_pred)
mae_lr = mean_absolute_error(y_test, Lr_pred)

evs_gb = explained_variance_score(y_test, gb_pred)
evs_rf = explained_variance_score(y_test, rf_pred)
evs_dt = explained_variance_score(y_test, dt_pred)
evs_lr = explained_variance_score(y_test, Lr_pred)

medae_gb = median_absolute_error(y_test, gb_pred)
medae_rf = median_absolute_error(y_test, rf_pred)
medae_dt = median_absolute_error(y_test, dt_pred)
medae_lr = median_absolute_error(y_test, Lr_pred)

print("Evaluation Metrics for Gradient Boosting Regressor:")
print(f"MSE: {mse_gb}\n R2 Score: {r2_gb}\n MAE: {mae_gb}\n EVS: {evs_gb}\n MedAE: {medae_gb}\n")

print("Evaluation Metrics for Random Forest Regressor:")
print(f"MSE: {mse_rf}\n R2 Score: {r2_rf}\n MAE: {mae_rf}\n EVS: {evs_rf}\n MedAE: {medae_rf}\n")

print("Evaluation Metrics for Decision Tree Regressor:")
print(f"MSE: {mse_dt}\n R2 Score: {r2_dt}\n MAE: {mae_dt}\n EVS: {evs_dt}\n MedAE: {medae_dt}\n")

print("Evaluation Metrics for Linear Regression:")
print(f"MSE: {mse_lr}\n R2 Score: {r2_lr}\n MAE: {mae_lr}\n EVS: {evs_lr}\n MedAE: {medae_lr}\n")
# Out:
# Evaluation Metrics for Gradient Boosting Regressor:
# MSE: 571258.2385960876
#  R2 Score: -0.06520954515567468
#  MAE: 649.8802012744194
#  EVS: -0.05486114901210226
#  MedAE: 620.5440576378192
#
# Evaluation Metrics for Random Forest Regressor:
# MSE: 584500.7527505154
#  R2 Score: -0.0899024975301077
#  MAE: 653.470884457478
#  EVS: -0.08465836745628752
#  MedAE: 650.7329000000009
#
# Evaluation Metrics for Decision Tree Regressor:
# MSE: 1003994.7083856304
#  R2 Score: -0.8721213531842555
#  MAE: 801.2064222873901
#  EVS: -0.8712146000427836
#  MedAE: 668.0800000000004
#
# Evaluation Metrics for Linear Regression:
# MSE: 545517.7811435591
#  R2 Score: -0.017212021229383367
#  MAE: 636.2126601097384
#  EVS: -0.010435885494528563
#  MedAE: 619.895145065444

# %%
models = ['Gradient Boosting', 'Random Forest', 'Decision Tree', 'Linear Regression']
mse = [571258.24, 584500.75, 1003994.71, 545517.78]
r2 = [-0.065, -0.090, -0.872, -0.017]
mae = [649.88, 653.47, 801.21, 636.21]
evs = [-0.054, -0.085, -0.871, -0.010]
medae = [620.54, 650.73, 668.08, 619.90]

fig, axs = plt.subplots(2, 2, figsize=(12, 10))

axs[0, 0].bar(models, mse, color='blue', alpha=0.7)
axs[0, 0].set_title('Mean Squared Error (MSE)')
axs[0, 1].bar(models, mae, color='green', alpha=0.7)
axs[0, 1].set_title('Mean Absolute Error (MAE)')
axs[1, 0].bar(models, medae, color='orange', alpha=0.7)
axs[1, 0].set_title('Median Absolute Error (MedAE)')

axs[1, 1].plot(models, r2, marker='o', linestyle='-', color='red', label='R2 Score')
axs[1, 1].plot(models, evs, marker='s', linestyle='--', color='purple', label='EVS')
axs[1, 1].set_title('R-squared (R2) Score and Explained Variance Score (EVS)')
axs[1, 1].legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# # Conclusion:
# Based on these metrics, Linear Regression seems to perform marginally better than the other models, followed closely by Gradient Boosting.
